# %% [markdown]
# # LAB 01a: Microsoft Entra PowerShell Module Setup
#
# This lab guides you through checking your PowerShell version, examining installed Microsoft Graph and Entra modules, and installing the required Microsoft Entra modules.

# %% [markdown]
# ## Step 1: Check PowerShell Version and Installed Modules
#
# Run the cell below to verify your PowerShell version and check which Microsoft Graph and Entra modules are already installed.

# %%
$PSVersionTable | Out-String
Get-Module Microsoft.Graph* -ListAvailable | Format-Table Name, Version | Out-String
Get-Module Microsoft.Entra* -ListAvailable | Format-Table Name, Version | Out-String
# Out:
# Name                           Value
# ----                           -----
# PSVersion                      7.5.1
# PSEdition                      Core
# GitCommitId                    7.5.1
# OS                             Microsoft Windows 10.0.22631
# Platform                       Win32NT
# PSCompatibleVersions           {1.0, 2.0, 3.0, 4.0…}
# PSRemotingProtocolVersion      2.3
# SerializationVersion           1.1.0.1
# WSManStackVersion              3.0
#
#
#
# Name                                                 Version
# ----                                                 -------
# Microsoft.Graph                                      2.25.0
# Microsoft.Graph.Applications                         2.25.0
# Microsoft.Graph.Authentication                       2.25.0
# Microsoft.Graph.BackupRestore                        2.25.0
# Microsoft.Graph.Beta                                 2.25.0
# Microsoft.Graph.Beta.Applications                    2.25.0
# Microsoft.Graph.Beta.BackupRestore                   2.25.0
# Microsoft.Graph.Beta.Bookings                        2.25.0
# Microsoft.Graph.Beta.BusinessScenario                2.25.0
# Microsoft.Graph.Beta.Calendar                        2.25.0
# Microsoft.Graph.Beta.ChangeNotifications             2.25.0
# Microsoft.Graph.Beta.CloudCommunications             2.25.0
# Microsoft.Graph.Beta.Compliance                      2.25.0
# Microsoft.Graph.Beta.CrossDeviceExperiences          2.25.0
# Microsoft.Graph.Beta.DeviceManagement                2.25.0
# Microsoft.Graph.Beta.DeviceManagement.Actions        2.25.0
# Microsoft.Graph.Beta.DeviceManagement.Administration 2.25.0
# Microsoft.Graph.Beta.DeviceManagement.Enrollment     2.25.0
# Microsoft.Graph.Beta.DeviceManagement.Functions      2.25.0
# Microsoft.Graph.Beta.Devices.CloudPrint              2.25.0
# Microsoft.Graph.Beta.Devices.CorporateManagement     2.25.0
# Microsoft.Graph.Beta.Devices.ServiceAnnouncement     2.25.0
# Microsoft.Graph.Beta.DirectoryObjects                2.25.0
# Microsoft.Graph.Beta.Education                       2.25.0
# Microsoft.Graph.Beta.Files                           2.25.0
# Microsoft.Graph.Beta.Financials                      2.25.0
# Microsoft.Graph.Beta.Groups                          2.25.0
# Microsoft.Graph.Beta.Identity.DirectoryManagement    2.25.0
# Microsoft.Graph.Beta.Identity.Governance             2.25.0
# Microsoft.Graph.Beta.Identity.Partner                2.25.0
# Microsoft.Graph.Beta.Identity.SignIns                2.25.0
# Microsoft.Graph.Beta.Mail                            2.25.0
# Microsoft.Graph.Beta.ManagedTenants                  2.25.0
# Microsoft.Graph.Beta.NetworkAccess                   2.25.0
# Microsoft.Graph.Beta.Notes                           2.25.0
# Microsoft.Graph.Beta.People                          2.25.0
# Microsoft.Graph.Beta.PersonalContacts                2.25.0
# Microsoft.Graph.Beta.Planner                         2.25.0
# Microsoft.Graph.Beta.Reports                         2.25.0
# Microsoft.Graph.Beta.SchemaExtensions                2.25.0
# Microsoft.Graph.Beta.Search                          2.25.0
# Microsoft.Graph.Beta.Security                        2.25.0
# Microsoft.Graph.Beta.Sites                           2.25.0
# Microsoft.Graph.Beta.Teams                           2.25.0
# Microsoft.Graph.Beta.Users                           2.25.0
# Microsoft.Graph.Beta.Users.Actions                   2.25.0
# Microsoft.Graph.Beta.Users.Functions                 2.25.0
# Microsoft.Graph.Beta.WindowsUpdates                  2.25.0
# Microsoft.Graph.Bookings                             2.25.0
# Microsoft.Graph.Calendar                             2.25.0
# Microsoft.Graph.ChangeNotifications                  2.25.0
# Microsoft.Graph.CloudCommunications                  2.25.0
# Microsoft.Graph.Compliance                           2.25.0
# Microsoft.Graph.CrossDeviceExperiences               2.25.0
# Microsoft.Graph.DeviceManagement                     2.25.0
# Microsoft.Graph.DeviceManagement.Actions             2.25.0
# Microsoft.Graph.DeviceManagement.Administration      2.25.0
# Microsoft.Graph.DeviceManagement.Enrollment          2.25.0
# Microsoft.Graph.DeviceManagement.Functions           2.25.0
# Microsoft.Graph.Devices.CloudPrint                   2.25.0
# Microsoft.Graph.Devices.CorporateManagement          2.25.0
# Microsoft.Graph.Devices.ServiceAnnouncement          2.25.0
# Microsoft.Graph.DirectoryObjects                     2.25.0
# Microsoft.Graph.Education                            2.25.0
# Microsoft.Graph.Files                                2.25.0
# Microsoft.Graph.Groups                               2.25.0
# Microsoft.Graph.Identity.DirectoryManagement         2.25.0
# Microsoft.Graph.Identity.Governance                  2.25.0
# Microsoft.Graph.Identity.Partner                     2.25.0
# Microsoft.Graph.Identity.SignIns                     2.25.0
# Microsoft.Graph.Mail                                 2.25.0
# Microsoft.Graph.Notes                                2.25.0
# Microsoft.Graph.People                               2.25.0
# Microsoft.Graph.PersonalContacts                     2.25.0
# Microsoft.Graph.Planner                              2.25.0
# Microsoft.Graph.Reports                              2.25.0
# Microsoft.Graph.SchemaExtensions                     2.25.0
# Microsoft.Graph.Search                               2.25.0
# Microsoft.Graph.Security                             2.25.0
# Microsoft.Graph.Sites                                2.25.0
# Microsoft.Graph.Teams                                2.25.0
# Microsoft.Graph.Users                                2.25.0
# Microsoft.Graph.Users.Actions                        2.25.0
# Microsoft.Graph.Users.Functions                      2.25.0
#
#
#
# Name                                           Version
# ----                                           -------
# Microsoft.Entra                                1.0.12
# Microsoft.Entra                                1.0.5
# Microsoft.Entra.Applications                   1.0.12
# Microsoft.Entra.Applications                   1.0.5
# Microsoft.Entra.Authentication                 1.0.12
# Microsoft.Entra.Authentication                 1.0.5
# Microsoft.Entra.Beta                           1.0.12
# Microsoft.Entra.Beta                           1.0.5
# Microsoft.Entra.Beta.Applications              1.0.12
# Microsoft.Entra.Beta.Applications              1.0.5
# Microsoft.Entra.Beta.Authentication            1.0.12
# Microsoft.Entra.Beta.Authentication            1.0.5
# Microsoft.Entra.Beta.DirectoryManagement       1.0.12
# Microsoft.Entra.Beta.DirectoryManagement       1.0.5
# Microsoft.Entra.Beta.Governance                1.0.12
# Microsoft.Entra.Beta.Governance                1.0.5
# Microsoft.Entra.Beta.Groups                    1.0.12
# Microsoft.Entra.Beta.Groups                    1.0.5
# Microsoft.Entra.Beta.NetworkAccess             1.0.12
# Microsoft.Entra.Beta.NetworkAccess             1.0.5
# Microsoft.Entra.Beta.Reports                   1.0.12
# Microsoft.Entra.Beta.Reports                   1.0.5
# Microsoft.Entra.Beta.SignIns                   1.0.12
# Microsoft.Entra.Beta.SignIns                   1.0.5
# Microsoft.Entra.Beta.Users                     1.0.12
# Microsoft.Entra.Beta.Users                     1.0.5
# Microsoft.Entra.CertificateBasedAuthentication 1.0.12
# Microsoft.Entra.DirectoryManagement            1.0.12
# Microsoft.Entra.DirectoryManagement            1.0.5
# Microsoft.Entra.Governance                     1.0.12
# Microsoft.Entra.Governance                     1.0.5
# Microsoft.Entra.Groups                         1.0.12
# Microsoft.Entra.Groups                         1.0.5
# Microsoft.Entra.Reports                        1.0.12
# Microsoft.Entra.Reports                        1.0.5
# Microsoft.Entra.SignIns                        1.0.12
# Microsoft.Entra.SignIns                        1.0.5
# Microsoft.Entra.Users                          1.0.12
# Microsoft.Entra.Users                          1.0.5

# %% [markdown]
# ## Step 2: View PowerShell Module Path
#
# This cell shows your PowerShell module paths where modules are or will be installed.

# %%
$env:PSModulePath -split ';'

# %% [markdown]
# ## Step 3: Install Microsoft Entra Modules
#
# This cell installs both the Microsoft.Entra and Microsoft.Entra.Beta PowerShell modules.
# Answer "Y" if asked about the untrusted repository.
#
# **Note:** This may take a few minutes to complete. The `-Verbose` flag provides detailed information during installation.

# %%
Install-Module -Name Microsoft.Entra -Repository PSGallery -Scope CurrentUser -Force -AllowClobber -Verbose
Install-Module -Name Microsoft.Entra.Beta -Repository PSGallery -Scope CurrentUser -Force -AllowClobber -Verbose

# %% [markdown]
# ## Step 4: Connect to Microsoft Entra
#
# Run the cell below to connect to Microsoft Entra. You'll need to authenticate in the popup window.

# %%
# <USERNAME>@M365x33461626.onmicrosoft.com
Connect-MgGraph

# %% [markdown]
# ## Step 5: Verify Connection and Run Basic Commands
#
# Test that your connection is working by running some basic commands.

# %%
# Get current signed-in user information
Get-MgUser -UserId (Get-MgContext).Account | Select-Object DisplayName, UserPrincipalName, Id

# %%
# List available commands from the Microsoft.Graph.Authentication module
Get-Command -Module Microsoft.Graph.Authentication | Sort-Object Noun

# %% [markdown]
# ## Step 6: Disconnect When Done
#
# Always disconnect from Microsoft Entra when you're finished working.

# %%
Disconnect-MgGraph
